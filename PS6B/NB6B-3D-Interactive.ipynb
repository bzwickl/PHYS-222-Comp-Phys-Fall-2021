# %% [markdown]
# ## Notebook 6B (3D interactive part) - Mon/Tues
# ### Vector plots in 2D and 3D to visualize electric and magentic fields
# ### Total points: 7
# #### PHYS 225 Intro to Computational Physics, Fall 2020

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The `%matplotlib notebook` command will make all the plots interactive/zoomable.
#
# **You must remember**
# 1. Call `plt.figure()` before each plot or things will get crazy (a new plot will appear in the spot where the last plt.figure() call was.  Dr. Zwickl will demo this at the start of lecture.
# 1. Do not switch back and forth between `%matplotlib notebook` and `%matplotlib inline` or you will likely have to restart the Kernel.  Just stick with one or the other. However, for the 3D plots, the interactivity is fantastic.

# %%
# %matplotlib notebook

# %% [markdown]
# # Example: 3D plotting a function $z = f(x,y)$ as a surface
#
# Some of the plot adjustments are a little different for 3D plots. For example:
# * **Adding the axes labels**
#     * `ax.set_xlabel("X (m)")`
# * **Adjusting the plot limits**
#     * `ax.set_zlim( (-10,10) )   # set z-limit from -10 to 10.`

# %%
# import the 3D plotting functions from matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
# this line allows for interactive plots 
# it is good for 2D and 3D plots

# set up the meshgrids
xrange = np.linspace(-5,5,11)  # 1D array of x values
yrange = np.linspace(-5,5,11)  # 1D array of y values
X, Y = np.meshgrid(xrange, yrange)  # create 2D arrays of X and Y values
Z = X**2 - Y**2  # compute 2D array of Z values

# define a new 3d figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# create the plot
ax.plot_wireframe(X,Y,Z)

# add labels to the 3D axes object
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax.set_xlim((-10,10))
ax.set_ylim((-10,10))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-10.0, 10.0)

# %% [markdown]
# # Task 6: Plot a surface for a function of your choice.
# * Copy the approach taken above to create a plot of a surface of your own choosing
# * Add comments to your code.

# %%
""" Create your own 3D surface plot here """


# Create the meshgrid

# Create the meshgrid of height values

# Create your plot

### BEGIN SOLUTION

### END SOLUTION

# %%
""" Create a nice looking plot with a clear calculation. 
Add a title to your plot """
assert True

# %% [markdown]
# # Task 7: Create a different 3D plot
# * Check out this [page of 3D plotting examples](https://matplotlib.org/gallery/index.html#d-plotting) and try out a different style, like a 3D contour plot or an amazing plot of the Lorenz attractor!
# ![3D Lorenz Attractor](https://matplotlib.org/_images/sphx_glr_lorenz_attractor_001.png)

# %%
""" Create your own 3D plot here.
The plot should NOT be a wireframe plot, but something else.
Make it look interesting, but don't spend forever. """


# Create the meshgrid

# Create the meshgrid of height values

# Create your plot

### BEGIN SOLUTION

### END SOLUTION

# %%
""" Create a nice looking plot with a clear calculation. 
Add a title to your plot.
If your plot doesn't make sense, you might lose points."""

assert True

# %% [markdown]
# # Example of 3D vector plotting
# These plots are somewhat challenging to interpret, but worth knowing how to make?

# %%
# Copy and paste your point_charge_field funcion here


print("Did you copy the pointchargefield() function to this notebook?")



# create the meshgrid
xrange = np.linspace(-1,1,6)
yrange = np.linspace(-1,1,6)
zrange = np.linspace(-1,1,6)
X, Y, Z = np.meshgrid(xrange,yrange, zrange)

# Calculate field of point charge at the origin
EX, EY, EZ = point_charge_field(X,Y,Z, 0,0,0,e)

# Create the plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scale = 2e8
ax.quiver(X, Y, Z, scale*EX, scale*EY, scale*EZ, normalize=False)

#Adjust the plot limits
ax.set_zlim(-1.5,1.5)
ax.set_ylim(-1.5,1.5)
ax.set_xlim(-1.5,1.5)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
# Out:
# Did you copy the pointchargefield() function to this notebook?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f89b13fa78e1> in <module>
#      13
#      14 # Calculate field of point charge at the origin
# ---> 15 EX, EY, EZ = point_charge_field(X,Y,Z, 0,0,0,e)
#      16
#      17 # Create the plot
#
# NameError: name 'point_charge_field' is not defined

# %% [markdown]
# # Bonus task 8: Create a 3D quiver plot of a dipole electric field (ungraded, time permitting)
# Don't be discouraged if the plot turns out wonky.
# 1. Consider normalizing the vector length (e.g., multiply the field vectors by a scaling factor to change their length in the visualization.) Because the x-y-z axes are in meters, but the vectors are electric fields in N/C, the magnitudes of lengths and electric fields may be vastly different. Scaling the vector lengths is an approach to deal with this.
# 1. Try different spacings of points to reveal the pattern more clearly.

# %%
""" 3D plot of an electric dipole. Use the example of the point change quiver plot as your starting point. """

# Create meshgrid

# Calculate the E-field of dipole

# Create the plots

### BEGIN SOLUTION ###
d = 1e-9
xrange = np.linspace(-1.5*d,2.5*d,10)
yrange = np.linspace(-2*d,2*d,10)
zrange = np.linspace(-2*d,2*d,4)


X, Y, Z = np.meshgrid(xrange,yrange, zrange)

#Z = z_fixed*np.ones( (len(xrange),len(yrange)) )

EXp, EYp, EZp = point_charge_field(X,Y,Z, 0,0,0,e) #+ point_charge_field(X,Y,Z, -d,0,0,-e)
EXe, EYe, EZe = point_charge_field(X,Y,Z, d,0,0,-e) #+ point_charge_field(X,Y,Z, -d,0,0,-e)
EX = EXp + EXe
EY = EYp + EYe
EZ = EZp + EZe

Emag = (EX**2 + EY**2 + EZ**2)**0.5
Emax = np.max(Emag)


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scale = d*1/Emax
print(scale)
ax.quiver(X, Y, Z, scale*EX, scale*EY, scale*EZ, normalize=False)
ax.set_zlim3d(-1.5*d,2.5*d)
ax.set_ylim3d(-2*d,2*d)
ax.set_xlim3d(-2*d,2*d)
print(ax.get_zlim3d())

### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8d6646e8c33a> in <module>
#      18 #Z = z_fixed*np.ones( (len(xrange),len(yrange)) )
#      19
# ---> 20 EXp, EYp, EZp = point_charge_field(X,Y,Z, 0,0,0,e) #+ point_charge_field(X,Y,Z, -d,0,0,-e)
#      21 EXe, EYe, EZe = point_charge_field(X,Y,Z, d,0,0,-e) #+ point_charge_field(X,Y,Z, -d,0,0,-e)
#      22 EX = EXp + EXe
#
# NameError: name 'point_charge_field' is not defined

# %% [markdown]
# # Bonus Task 9: Visualizing the equation of motion for a physical pendulum at large angles (ungraded, time permitting)
# Consider a rigid bar of uniform thickness that can swing about one end. It can be modeled as a physical pendulum that can swing over large angles and obeys the equatino of motion
# $$\tau = -\frac{1}{2}Lg\sin \theta = I\ddot{\theta}$$
#
# There is an interesting way to visualize the equations of motion known as a **phase space** plot.
# * `X` becomes the range of "position" coordinates $\theta$
# * `Y` becomes the range of "velocity" coordinates $\omega$
# The vector components are determined by the equations of motion
# * `Vx` is the rate in change of position so $V_x(\theta,\omega) = \omega$
# * `Vy` is the rate in change of velocity so $V_y(\theta, \omega) = -k\sin\theta$
#
# Make a quiver plot of the above vector field that represents the equation of motion in phase space. Make sure to label axes.

# %%
""" Calculate the vector field """
# %matplotlib inline
# Create your meshgrid

# Calculate the vector field representing the physical pendulum

# Create the plots

### BEGIN SOLUTION
xrange = np.linspace(0,3*np.pi,20)  # 1D array of x values
yrange = np.linspace(-3,3,20)  # 1D array of y values
THETA, OMEGA = np.meshgrid(xrange, yrange)  # create 2D arrays of X and Y values
THETA_dot = OMEGA  # compute x-component of vector field (2D array of values)
OMEGA_dot = -np.sin(THETA) # compute x-component of vector field (2D array of values)

plt.quiver(THETA,OMEGA,THETA_dot,OMEGA_dot)
plt.xlabel("$\\theta$ (rad)")
plt.ylabel("$\\omega$ (rad/s)")
plt.savefig("Quiver.png")

plt.figure()
plt.streamplot(THETA,OMEGA,THETA_dot,OMEGA_dot)
plt.xlabel("$\\theta$ (rad)")
plt.ylabel("$\\omega$ (rad/s)")
#plt.savefig("Streamplot.png")
### END SOLUTION
